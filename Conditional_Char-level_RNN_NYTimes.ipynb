# %% [markdown]
# # Conditional Word-level RNN

# %% [markdown]
# ## Requirements
#
# You will need [PyTorch](http://pytorch.org/) to build and train the models

# %%
import unicodedata
import string
import re
import random
import time
import math
import ast

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

# %% [markdown]
# Here we will also define a constant to decide whether to use the GPU (with CUDA specifically) or the CPU. **If you don't have a GPU, set this to `False`**. Later when we create tensors, this variable will be used to decide whether we keep them on CPU or move them to GPU.

# %%
USE_CUDA = True

# %% [markdown]
# ### Indexing words (you can ignore, was trying to do word-level embedding)
#
# We'll need a unique index per word to use as the inputs and targets of the networks later. To keep track of all this we will use a helper class called `Lang` which has word &rarr; index (`word2index`) and index &rarr; word (`index2word`) dictionaries, as well as a count of each word `word2count` to use to later replace rare words.

# %%
SOA_token = 0
EOA_token = 1

class Lang:
    '''Instantiates an object class that can keep its own word index count'''
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOA", 1: "EOA"}
        self.n_words = 2 # Count SOA and EOA

    def index_words(self, sentence):
        for word in sentence.split(' '):
            self.index_word(word)

    def index_word(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# ### Reading and decoding files
#
# We need to create word indexes for the Tensors to train a Word-level RNN.
#
# #### Normalize text
#
# The function below normalizes the text in the lead paragraph, taking out certain symbols that will create two indexes (Bush and Bush's, for example). We're also adding a space to the HTML tag `<p>` and `</p>` so they will be treated as separate words

# %%
def normalize_string(s):
    '''Function meant to clean up lead paragraph strings, removing a different combo of items'''
    # Some of these are very crude and may need to be cleaned up
    translator = str.maketrans('', '', r'''.,'"''')
    s = s.lower().strip()
    s = re.sub(r"<p>", r"<p> ", s)
    s = re.sub(r"</p>", r" </p>", s)
    s = s.translate(translator)
    s = re.sub(r"[^a-zA-Z!?/<>[0-9]]+", r" ", s)
    s = re.sub(r"</p><p>", r"</p> <p>", s)

    return s

# %% [markdown]
# To read the data file we will split the file into lines, and then split lines into pairs.
#
# We will also create a Lang instance, which will create a word2index and index2word we'll use for encoding / decoding Tensors.
#
# Also, some articles may not have keywords associated with them. We will drop those while reading in the data.

# %%
all_letters = string.ascii_letters + " .,;'-<>/"

# Turn a Unicode string to plain ASCII, thanks to http://stackoverflow.com/a/518232/2809427
def unicode_to_ascii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

def read_lines(lang_class_name, doc):
    '''Takes in the kw_text pairs, normalizes and tokenizes'''
    print("Reading lines...")

    # The input document is a list of keyword and text pairings
    # joined by tab /t and then separated by a line break /n

    # Read the file and split into lines
    lines = open(doc).read().strip().split('\n')

    # Split every line into pairs and normalizes pair[1] which is text

    pairs = [l.split('\t') for l in lines]
    normalizationFail = 0
    for pair in pairs:
            
        try:
            pair[0] = pair[0]
            pair[1] = normalize_string(pair[1])
            pair[1] = unicode_to_ascii(pair[1])
        except:
            print("Issue with normalizing strings")
            pairs.remove(pair)

    
    lang_class_name = Lang(lang_class_name)
    return lang_class_name, pairs

# %% [markdown]
# The full process for preparing the data is:
#
# * Read text file and split into lines, split lines into pairs
# * Normalize text
# * Make word lists from sentences in pairs

# %%
def prepare_data(nyt_russ, doc):
    '''Preprocesses text data, returns a Lang object and list'''
    all_categories = set()
    
    # Split, organize, preprocess and clean text

    nyt_russ, pairs = read_lines(nyt_russ, doc)
    print("Read %s sentence pairs" % len(pairs))
    
    # Using Lang object returned from read_lead_kw,
    # Create a word index list

    print("Indexing words...")
    for pair in pairs:

        try:
            nyt_russ.index_words(pair[1])

        except:
            print("Issue Indexing")
        
        try:

            all_categories = ['putin','international trade', 'economic conditions and trends',
                             'defense and military']

        except:
            print("Issue creating categories")
    
    
    return nyt_russ, pairs, all_categories

nyt_russ, pairs, all_categories = prepare_data('nyt_russ', 'test_outfile2kw-l.txt')

# Print an example pair
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 111 sentence pairs
# Indexing words...
# ['economic conditions and trends', '<p> president boris n yeltsin vigorously defended his government and economic reforms today before a skeptical congress of peoples deputies and warned the lawmakers not to short-circuit russias transformation by diluting presidential power </p> <p> mr yeltsin and his chief economic adviser yegor t gaidar gave strongly worded speeches that acknowledged some failures in policy and performance but said the economy was improving and would stabilize by the end of the year </p>']

# %% [markdown]
# ## Preparing for Training
#
# Grab a random training sample

# %%
# Get a random sample
def random_training_pair():
    training_sample = random.choice(pairs)
    return training_sample

print(random_training_pair())
# Out:
# ['defense and military', '<p> since the cold war ended no other event has so divided the west and russia as the nato bombing of yugoslavia the chasm is so deep that even words have taken on opposite meanings while americans and europeans talk about the genocide of kosovo albanians by serbs many russians talk about the genocide of serbs by american bombs </p> <p> here the chief villains are president clinton and nato variously described as fascists and bullies president slobodan milosevic of yugoslavia widely identified in the united states and europe as the man responsible for a vicious campaign of ethnic cleansing is seen by many here as a defiant patriot defending the sovereignty of a country attacked by foreign aggressors </p>']

# %% [markdown]
# For each timestep (that is, for each word in a training sequence) the inputs of the network will be `(category, current word, hidden state)` and the outputs will be `(next word, next hidden state)`. So for each training set, we'll need the category vector, a set of input words, and a set of output/target words.

# %% [markdown]
# Since we are predicting the next letter from the current letter for each timestep, the letter pairs are groups of consecutive letters from the line - e.g. for `"Apple Banana Compost Diderot <EOA>"` we would create ("Apple", "Banana"), ("Banana", "Compost"), ("Compost", "Diderot"), ("D", "EOA").
#
# ![](https://i.imgur.com/JH58tXY.png)
#
# The category tensor is a tensor of size `<1 x n_categories>`. When training we feed it to the network at every timestep - this is a design choice, it could have been included as part of initial hidden state or some other strategy.

# %%
# CONVERT BELOW

n_letters = len(all_letters) + 1 # Plus EOS marker
EOS = n_letters - 1


n_characters = len(all_letters) + 1 # Plus EOS marker
EOA = n_characters - 1
all_characters = all_letters

# %%
n_categories = len(all_categories)
all_characters = all_letters
n_characters = len(all_letters) + 1 # Plus EOS marker
EOA = n_characters - 1

# Vector with multiply entries for each category present

def make_category_input(categories):
    tensor = torch.zeros(1, n_categories)
    if (type(categories) == 'list'):
        for i in range((len(categories))):
            li = all_categories.index(i)
            tensor[0][li] = 1
    else:
        li = all_categories.index(categories)
        tensor[0][li] = 1
        
    
    tensor = Variable(tensor)
    if USE_CUDA: tensor = tensor.cuda()
    
    return tensor

# Return a list of indexes, one for each word in the sentence
# Pad to meet MAX_LENGTH (needed because issues arose of variable input length)


def indexes_from_input(input, lang):
    wordIndex = [lang.word2index[word] for word in input.split(' ')]
        
    return wordIndex


# One-hot matrix of first to last letters (not including EOA) for input

def make_chars_input(chars):
    tensor = torch.zeros(len(chars), n_characters)
    for ci in range(len(chars)):
        char = chars[ci]
        tensor[ci][all_characters.find(char)] = 1
    tensor = tensor.view(-1, 1, n_characters)
    
    tensor = Variable(tensor)
    
    if USE_CUDA: tensor = tensor.cuda()
    
    return tensor

# LongTensor of second word to end token (EOA) for target

def make_target(line):
    letter_indexes = [all_characters.find(line[li]) for li in range(1, len(line))]
    if -1 in letter_indexes:
        ix = letter_indexes.index(-1)
        letter_indexes[ix] = 94
    letter_indexes.append(EOA) # EOS
    tensor = torch.LongTensor(letter_indexes)
    
    tensor = Variable(tensor)
    
    if USE_CUDA: tensor = tensor.cuda()
    
    return tensor

# %% [markdown]
# For convenience during training we'll make a `random_training_set` function that fetches a random (category, line) pair and turns them into the required (category, input, target) tensors.

# %%
# Make category, input, and target tensors from a random category, line pair
def random_training_set():
    category, lines = random_training_pair()
    category_input = make_category_input(category)
    line_input = make_chars_input(lines)
    line_target = make_target(lines)
    
    return category_input, line_input, line_target

# %% [markdown]
# # Creating the Network

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        print(input_size, hidden_size, output_size)
        self.i2h = nn.Linear(n_categories + input_size + hidden_size, hidden_size)
        self.i2o = nn.Linear(n_categories + input_size + hidden_size, output_size)
        self.o2o = nn.Linear(hidden_size + output_size, output_size)
        self.softmax = nn.LogSoftmax()
    
    def forward(self, category, input, hidden):
        input_combined = torch.cat((category, input, hidden), 1)
        hidden = self.i2h(input_combined)
        output = self.i2o(input_combined)
        output_combined = torch.cat((hidden, output), 1)
        output = self.o2o(output_combined)
        return output, hidden

    def init_hidden(self):
        hidden = Variable(torch.zeros(1, self.hidden_size))
        if USE_CUDA: hidden = hidden.cuda()        
        return hidden

# %% [markdown]
# # Training the Network
#
# In contrast to classification, where only the last output is used, we are making a prediction at every step, so we are calculating loss at every step.
#
# The magic of autograd allows you to simply sum these losses at each step and call backward at the end. But don't ask me why initializing loss with 0 works.

# %%
def train(category_tensor, input_line_tensor, target_line_tensor):
    hidden = rnn.init_hidden()
    optimizer.zero_grad()
    loss = 0
    
    for i in range(input_line_tensor.size()[0]):
        
        output, hidden = rnn(category_tensor, input_line_tensor[i], hidden)

        loss += criterion(output, target_line_tensor[i])

    loss.backward()
    optimizer.step()
    
    return output, loss.data[0] / input_line_tensor.size()[0]

# %% [markdown]
# To keep track of how long training takes I am adding a `time_since(t)` function which returns a human readable string:

# %%
def time_since(t):
    now = time.time()
    s = now - t
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %% [markdown]
# Training is business as usual - call train a bunch of times and wait a few minutes, printing the current time and loss every `print_every` epochs, and keeping store of an average loss per `plot_every` epochs in `all_losses` for plotting later.

# %%
n_epochs = 100000
print_every = 10
plot_every = 5
sample_every = 100
all_losses = []
loss_avg = 0 # Zero every plot_every epochs to keep a running average
learning_rate = 0.001

rnn = RNN(n_characters, 80, n_characters)

# Move models to GPU
if USE_CUDA:
    rnn.cuda()
    
optimizer = torch.optim.Adam(rnn.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

start = time.time()

for epoch in range(1, n_epochs + 1):
#     rnn.zero_grad()
#     rnn.hidden = rnn.hidden_init()
    
    output, loss = train(*random_training_set())
    loss_avg += loss
    
    if epoch % print_every == 0:
        print('%s (%d %d%%) %.4f' % (time_since(start), epoch, epoch / n_epochs * 100, loss))

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
        
    if epoch % sample_every == 0:
        category, lines = random_training_pair()
        generate(category, '<<<')
# Out:
# 62 80 62
# 1m 34s (10 0%) 3.8810
# 3m 3s (20 0%) 3.0305
# 4m 17s (30 0%) 3.1716
# 5m 43s (40 0%) 3.0139
# 7m 0s (50 0%) 2.9776
# 8m 3s (60 0%) 2.9073
# 9m 29s (70 0%) 2.8878
# 11m 5s (80 0%) 2.8606
# 12m 33s (90 0%) 2.8361
# 13m 45s (100 0%) 2.8591
# <erae  t ene hee no o   os  en    t suases s ieiitee t  artonit clont   l ctte liimssaiie in the pb    yhei r   t  a  ee snt t nta yed t ea e e ioe teth  atteeo ea taenee    a  itint  den i n  r ne   re e nsanre <ne  s a  ave n ats e  arein oio  t  s nat r ha tse an a nr e  nese  aiae  d e te    tise tn irte ti ie iine   snt e tt rreiuisl   er aupe t pmli  tha   art n  n   rhaota octe tsss a d  it ttt iinise nc e nl  tptooi  n a e rht nis frea s ta  net   oit e  a s to w th sisa th etie  e   shse
# <the  aof sa r ae  a ce e  sou s raneeo whinai  stme  itt o nss s  t itta ar raua    a mei  ai esne t ourne  sts n  rtseen a  rth o tte as ohcet t on   nwuasnie  pte enenay s n e snntn  toepbil friii e  s t nts  tpen  se i  t se sre et  s i   n  ae ti tle s    attt asa al as  nn ie n titnrfe  tas htt i as  nre  s t ome ie   t als  hesorr   heia n  i s   r   ee cat oe  einp nie  eine  t e os t  a ens lott e ae et tt e   te  ci  e s rler   o    sinntins  t aeiet  nes sian md h sn tr i t ta ae nhe
# <<inore  s dren d s  e r reeo    d    o e r neli s inseaar ians tetite o  so ey trre  t ntnht  r el on  t  e  ere   nn t o s  tn  eis   c tr   s  dte rd ne  e s n troeia an tas  iieha e  tli  ose s  reaure e lsoro    n  s o e s es n ie st eaner  nhenlrue h an  a ae rt  ot n tansan  tettin rn  a cstn linrr  arie  ont sto a is   e    ne as tid   i o e i yy  l<p me m as iue  et h trenen er t tuaont dei le et s n ao  ieaa   eht rein  pe o   ss n tis s eot ttns   aeun  t  p  lun  in   h t ons e ieare
# 15m 24s (110 0%) 2.7981
# 16m 54s (120 0%) 2.8165
# 18m 31s (130 0%) 2.7632
# 19m 28s (140 0%) 2.7026
# 21m 14s (150 0%) 2.6848
# 22m 26s (160 0%) 2.7143
# 23m 32s (170 0%) 2.6519
# 24m 47s (180 0%) 2.5985
# 25m 52s (190 0%) 2.7404
# 27m 24s (200 0%) 2.5666
# <wEin pi k  one  for featde ot  n hon thes tatoan  an the an d ant o mol  oed thee  an  ors rinl re t sa in  oon thn en  te ene s ppit f mi the to  hl thie  an se d linon s thtos  the tine tore  it torertnin ider  orel  hare ar hes ter s  n winre  io fo s tre the sh thea sinior the re ke les tor tea san erw  ie til  o era in  ton the t me an mia < p c ostirethe  y an io y tithentri  f thed oe n srere an ii d  a sre  e ses tian he aon an onre iolilil erhed set  e tor  in tns tan te tea r an  ioriy
# <Hnjhes tha to tore to thar the core por dn p ae  eb ee aoh ond ean ni sa thoa the  ins ohetale tto thed in sose   o toadtser thi  ait an thaoe aor tae iren in saos ate tot os th insun s in tan d  onee  cnos ans tons i tot e s ton tont o  nhe are thatsas we ae  he  toc  an s an no mr  or oit eh  hes on s on r sar re s ea the rio too do toan to the d e  s  fes an l goate t on s ir tha r the  onn eothe tot ohe eece tottor to the sor as hoot on s co at  tit n tia the s tis ra the  ore lon whe etic o
# <<dlVeathesran ther ore thes the  ca g he in potners tae thinnarin te  on inn sh oro  hon thon sins  or the din ror an in mche  ad rel ro phef ihete the  o re  om  on an lho re hon o  in  the ce the s ag t te ia s t ae he ther rur  f  s thcred linsi toa  ototo sae ii roo  ies ken ranseethe thian tar enn s in atuet anseig te  o ashe tn sus the nf onthon rores anttan sit tio tove  en  the se  he  r sa  uhis honn sie tin aa  to a ant a  rints ireton eet t te sh ca th a si  ore  o ee an  i l redd ran
# 28m 52s (210 0%) 2.5058
# 30m 56s (220 0%) 2.5224
# 32m 7s (230 0%) 2.4802
# 33m 36s (240 0%) 2.4433
# 35m 0s (250 0%) 2.4491
# 36m 14s (260 0%) 2.3997
# 37m 30s (270 0%) 2.4141
# 38m 52s (280 0%) 2.3932
# 40m 14s (290 0%) 2.4129
# 41m 38s (300 0%) 2.3870
# </p><p><p><p> phe in the thiler cathederun aoca the the the the po thed ba thes an phe the tor son mati the biend sitor ali the the senirere the the don ian tan in ean whe the s ans wot tar  uri ser an thertithe the me irorelatian there chat an the ince sa the the an tanin itn the  on riles ins  hate the toncon the ther anles ind thetrac was nusgin the mel soriis in ar ha the matirit sin the tir so ce tor anbe an thar st tres an are an  the to the tas the chat ron int aited be at ofin s an ing in
# </p><p><p><p> the desthe an the to erin  fin  or mit the tee the an the the an the tor mils ans sor shar ine th th ce taid the the  he t an at wion rin tor in in thos en the  ale the s the toap the the the the theerende sn bisithe the and then tore s fhel sas the toat on thetin the thed toen rin an thevin the the an ann in ale the an me there bal the sint thes the she thes th the the yhes  he mns an thee the  aot in s sre in the then pare the the the cor ir besn thet on che mapar the thes an wor
# <d the the  aals one won thitslale the sat er theat on  an se s in the the the thai the the the then shes ohe nacins art an  he lis an so siti so te he thenis an the on ang the the in the thete th cof ho the than tore and s tho the the athe rale lere s ont anvd ond the che the re the opate can in wan an cor sofe the am we the  het er the to tor the wat one che res an  anta the the n in tos sn siin the the the th an ware the conting an onte be i  of ar  an in the the s an in se toan ba thoas an se
# 42m 50s (310 0%) 2.3525
# 44m 9s (320 0%) 2.3525
# 45m 53s (330 0%) 2.3410
# 47m 8s (340 0%) 2.3926
# 48m 34s (350 0%) 2.2913
# 49m 47s (360 0%) 2.2734
# 51m 1s (370 0%) 2.3161
# 52m 43s (380 0%) 2.3002
# 54m 2s (390 0%) 2.3004
# 55m 33s (400 0%) 2.2576
# </p><p><p> the  fot of on ar mond and aly the sea the tfar tove ser the sad te thoceread an the the the antrer ans thias the tul the the cons in the san tarthe the ind an an ane an  antion bot are and acg and the the the sin mong als rof ther che te the thas rethe the the the cof undan phe torile tamis an ins the the the mewin an tor rowand anthe s  he sean an the thil cuen hot on  rot ing onthe be s ing tho s an ton the an thir to weringes ontimint in they ensider ba the in aleas ind cace the to
# </>><p><p> sop roce aom the then at thas in cond the  hate vemen the toras ban ale an olecind the a san  aad ari the s ton the cerind the tus on  ored thes on the the dusing and waicand ovend at on wonting saof an in the ing tor of an the pe the the bith the the suthe sing andition thin tomand the the the the the the tar an tiche las be anthe  ran sile costine she that at rent  for bute cored at onder torl be tong soind be benowe t or the al in the sithe te tostin thal dome the mins thin dede cor
# </p><p> phe the s an pon che d iss on in aly an the benti the an bow an at forter co morn mald con an an th tond thet to se has the ste se terincen tor  an an the  ar ahe the te that in ingice the thecuny and pot in wores to simin thi  the  re than an  he the  farte the erline te ble an ane ting or an of on en the  fon an an te the  feon whe ther  ave be me s whe thes on of the thi  af ches mhe ins an ins whe the the  on in thes an an the ser the the so the  he the the in shitl worlin and wias on
# 57m 6s (410 0%) 2.2450
# 58m 33s (420 0%) 2.3213
# 59m 42s (430 0%) 2.3458
# 61m 27s (440 0%) 2.2269
# 63m 4s (450 0%) 2.2357
# 64m 24s (460 0%) 2.2874
# 65m 42s (470 0%) 2.2022
# 67m 6s (480 0%) 2.2136
# 68m 8s (490 0%) 2.2141
# 69m 32s (500 0%) 2.2404
# </>><p> an arid the  pathe the come lis ind core th pos int tous int ing of in an the  on comiche the sin of the wate cof an tho bes enong or be ding re the thot in ithe the  omenas ar sied on pe ses bot cof rabe the ther the are tion the ruthe puce raiy in the for ion costa the the couss an ion whe no the frecher conas and the  the poune the menict an wemang the  foreras ane the sees and ane proun ser cofor she the the the the she s are the s un co lope the meve the fons ion thit conin the  he t
# </>><p> rustion to wion the turis ante the tes an in the soris cors an cow wo the the tion ar an lon ansian the the te tor of the gealat on thet th tion se theradlin the condes ing the tili s in the thica cowirn them we tus of an che the mor bered an the soin der the ted the  fote mithe the the se pastir  of ramingo tha the the the nape the wion the he ans inide to tien cor and the the  fond </p><p> on  he the stion an the that  thes ante the dessor cous sor the te tog ratin sute cong the the on
# </p><p> che the fint the alit of mosice therr alin the ta tered the sion the this an ber int and in the the seat an un relin the porecor in thes an on bo cat uthe ton sion the  the s an the the he an moris shicy an the tore ste bore the and ander saind be the seatir tor ree the tomestere the ther the porisinw an watin the the fore the mare tors the ione to punt an int on an or ing int ratie that lover tion in mand wha de the somint er the tore ans ta the mand af rhe wont in the the tore ile te th
# 70m 57s (510 0%) 2.2213
# 72m 12s (520 0%) 2.2469
# 73m 36s (530 0%) 2.2243
# 74m 51s (540 0%) 2.1811
# 76m 13s (550 0%) 2.2410
# 77m 35s (560 0%) 2.1890
# 78m 50s (570 0%) 2.1319
# 80m 5s (580 0%) 2.1949
# 81m 13s (590 0%) 2.2640
# 83m 18s (600 0%) 2.1949
# </p><p> the the mas patid the ton the nget in the ane the costith of reat  wari nithe ctor trenten  ares at the she gho che maling an the mastid the mans in fore coriss nor wang of russ of tho fution  and the forking inat of becco he the sus and den caste or ghe the th she goming ter bel ins an warget on alliand the cons ane tho s of ion the sian the hat tes ant the prece were mand ind cons yonat on wong seeming an the the the naple the theg the the ans and the rele an se the and whe the the thal
# </p><p> po the ther the inting cowith  unsing on the the contin sars an ar stid the che pare toos the tove ale red ins shet bat romenger set incenss an ande ss inged thin cons the koricling sedest an ine thet an the nevercen therin thes an countr in and inged the  offris in aremang sound the song sute s as fore sed se the pores and bering the sunt af the the d se that re to sesing the tha th that red int an fore sareas of ther snat and ara for cofint ons al torstin suplo t andet er and thon thar
# </>><p> be the the pover this of then at the ghe the thit rored the mas an the then s at on the wornthe wore par bal the of the t of the an ind re thin the cat ong cons chess be lustien the the the and at that an con wariin tho che hat ond tha s an coves the the the the  wore cestor and and ta an co porte the sathe  has ond and an sas and an and </p><p> the now the nat on the wor bean te the wion satl engento cors ins the an the of tha dent the nutila d chate theras tar in the s coullas on che se
# 84m 36s (610 0%) 2.1833
# 85m 36s (620 0%) 2.1767
# 86m 39s (630 0%) 2.1985
# 88m 12s (640 0%) 2.1322
# 89m 28s (650 0%) 2.1540
# 91m 27s (660 0%) 2.1469
# 92m 36s (670 0%) 2.2230
# 93m 49s (680 0%) 2.2039
# 95m 56s (690 0%) 2.1789
# 97m 1s (700 0%) 2.1335
# </p><p> tha s aid in all the ramestit an souplin the saref are fion conter withe to powe the the sed the torminis ins in s sores ins ander hes ing at ber bullin the se paling the the kere warris song gorestin arestis suliser and the to puls are cerment an wous our tor soll atico butis an the somprat on the beathe the siand siss ian whed bithe ane tor sion and at ho sast an of re sicher an ther ere the the the merount he the uthe and rodestor the inis de anceruch ar the teres and pestion are anien
# </>><p> on the ther parmas are the the toon ant billint an trele sian aid the cons wor she and be the on the mancove borlicmendecs axpres as af an ware ction int she anin thit the ther ans he thathe and ion ion rof of ar an ins ther ingetre chepreat anconde tore fort on pores ingater ion the the tive the s ande chis an ar the the seat to pricall ane sous ar be the bes in the the he seas ion colled in shit whil che leshe sache iliche ha paris in the ssine wathe semes boun the thares incullicingres
# </>><p> the wer sain ine the lite and ar en ther colitin the coullin la the ingressit wert an the se thece comeres ing urise ales bemon the the to shir mank wes on the hare iad an me to pererey ine tore taal </p><p> the whie the arment of thing the tors of the thes ar the the bone andes an the reling ares the ar pores ano the the conas bo he sestin er ale the s axpere the anden that arsint ins af rementit sustiat ans allint and ar and inald the tove the prop erover inas wacin the tor and he buse
# 98m 23s (710 0%) 2.1961
# 99m 52s (720 0%) 2.1960
# 100m 55s (730 0%) 2.1168
# 102m 10s (740 0%) 2.1840
# 103m 16s (750 0%) 2.1882
# 104m 21s (760 0%) 2.0704
# 105m 51s (770 0%) 2.1711
# 107m 3s (780 0%) 2.1861
# 108m 24s (790 0%) 2.1982
# 109m 56s (800 0%) 2.1799
# </p><p> the salle the hon in the the he perente ruthe s pout an whin mo the were recrecund ar and ye the the ender tare dere the  fore an prithe hed thit se trewith  hate no sale core the ate of sove the  ureding suss an soicalling tho for seinat on the ulid the cation wat the ter tha the tull in the the sine and wat  ha palle the couter ----usit  hare the noully seat of rment the far ind the and s ail  of ruthe to the on theans and ar anden iond ther and the nouling ous ion and an he the be the
# </p><p> the seallina the tha peringed and the  thate the fore ha we posin bem co prome tion the mere the in the that an of the ce mull in the meres be the seraing the wer ens to tor and ice the tha jors ing at or and the rustit of tha d an chey shat re seato s an the at the  foutila the storas whe s and the sand yes woul the se kever the wer sation tor and nce pore the cone the fore the wark an an was an buthe and ar whal the and the sugrres and ras the te the rus the  fithe he fertere be tha d a
# </p><p> an ous be per the scoust res in and prepreat on the the mand and hate and be then mone tha dand aid an urs and the ares on ar peed don ard aid me the rald al sice mentins ale tore sely an the were tor me siin d ouss of in sos ar matin st hes an ane porint are the tha d wove </p><p> pre that an mint the pore the sead it en coucledin tor and bel the t on at the he for and are the porto no he fore mr phes an on and at bat en tha d maict the dere the the stous an ofor wall an are the he prom
# 111m 21s (810 0%) 2.1797
# 112m 9s (820 0%) 2.0875
# 113m 23s (830 0%) 2.1668
# 114m 52s (840 0%) 2.1296
# 116m 11s (850 0%) 2.1497
# 117m 54s (860 0%) 2.1275
# 119m 23s (870 0%) 2.1478
# 121m 10s (880 0%) 2.1377
# 122m 46s (890 0%) 2.2101
# 124m 0s (900 0%) 2.1442
# </p><p> bus and tho ing toram no for and be tore tha d af the protid sa co cored prome the cound res walite the or the bere the  nisto te fores in couts for and to whek rithe ston  he </p><p> the buring the theas in the ares are wall </p><p> me tore the that co fred and bal no me bers the the disn buthe the and and of of ins re ther buras and thar come the ther the the thit con the fores on the he pure the allas of the couth  foritis son the the sowsin th iol mand as and che en the he restien ano
# </>><p> the sove me the mand and cof te and ben mant ande ce that waly the sion in the the the mrensin st at re tored oud wenn and bo bine the fion to the red ine s mprothe the whel the the weren in the mant the the sondith the lat wered ing tonto the he mestacl an in ald be the of the tre the saidin inge mente the that were the theal the arg the his ion tres io the onte bund ce the in the enten the the of the duss of theve baid wat we lle prate s are ais und cowask the  fored the te tore the ore
# </p><p> tho nore couto s </p><p> the checistien war ming to gemeracon the s the ret ins and furatit tofs in ond the stame int on har inoto for tho dere sion the sont sitid that she coffin as arewitha the ber the thil stis in sice mand cofming to theve mingrenat on the sostit an lof and int rover ingan tor whe sid on wathe the d meres in onceris the ther terecandens </p><p> in the thar ware stien the ksitis in s and ant ras ind and on the chate and sove and beat of on the con the pore sing the the
# 125m 8s (910 0%) 2.1589
# 126m 33s (920 0%) 2.0964
# 128m 4s (930 0%) 2.1686
# 129m 35s (940 0%) 2.1133
# 130m 46s (950 0%) 2.1270
# 132m 14s (960 0%) 2.1256
# 133m 27s (970 0%) 2.1723
# 134m 32s (980 0%) 2.1558
# 135m 52s (990 0%) 2.1675
# 137m 13s (1000 1%) 2.2002
# </p><p> the s afre the will the said wher and the re mentin the patsin ss erest male the s ander the the che conte the mand mandent y of the stor ss are buthe s were thian und ropperis we promal of the vecerom tha loptore dand nomen the promend shathe s bats ing the forthar d pofin the ded sove the stion the ntimest on dund bat ingond por and cament the purit and the for the the surs ablon thay mand sos ine the werthe we ther then and the he thes ars in space the the prome the antin ss are treg t
# </p><p> me nor the day sed the fort pance mrat an precing the dial would an hand boulling poreer ant at of rablin the pore the pore the s aned the bat o- and the tha dema mong tone to muin the re menar ghea chis pore se ware wo has and be the couss an har oftit che forsis ald an the ho n buciny and and of on ate the has with the chathe he thear ans pestith in the councr blond the she whe the ring the  havecon the lered the pores maressin wathe the der the an the murist on the the chere pestin the
# </>><p> on at ous in lostion ef the the nead ersist an the thithe the the he mere the his monge an  ofere se purtion the ha dien der be the for praten the ger sure ply tren with an  apporis the  hat are ha d ane furint er mecante topperes in suthe foret by then the the rade that and ded che then werer ne and ars inile s ars and pontin the s ineder ing he the furion ar buthin thes and rove tor sive the prand the medens an whin ssataid so premint the coust ous the sute the the meremand an the or th
# 138m 43s (1010 1%) 2.1569
# 140m 20s (1020 1%) 2.1320
# 142m 13s (1030 1%) 2.1241
# 143m 34s (1040 1%) 2.1644
# 144m 52s (1050 1%) 2.1292
# 146m 3s (1060 1%) 2.1050
# 147m 16s (1070 1%) 2.1368
# 148m 27s (1080 1%) 2.0913
# 149m 54s (1090 1%) 2.1709
# 151m 10s (1100 1%) 2.2076
# </p><p> the cinas ar blion </p><p> pratien  foread tha s athe se mand the sed that ing ter have the perterug the coress and ther in the inital cond an ers ofil the whis and aid the s athe will and be thet and the the rusingor the  fures inat an the to permastor pastow in trous in the that wa thias and milis dat on the rustin the red and thit and wark an ha morkint of the  hate that in the rathe chate he the comint ar tove cable pors in in the reveres ffick the derale ther onthit ingeret the arati
# </p><p> buts at chay lo d ares sear whic susian tha formeras and at the sate wher werto he pariss stien the cous ias din the pratse way sivering ing tad that of the chas undere the the pertians and the cowaris perice ande the rustion wore stome co perted th the ther more tha seat of the sund the the chate of the the remant ghat of tion by he couplist at in ther and haveres ing the ras ive th the sustit ras inain the ve cone bat hat me this  would inan the contire soras </p><p> the s ared in the h
# </p><p> the sustion warngat the sinta to frestan rfon one dero the cos and the coming on ane tho really whe the dering tray whe capleno co pund be the cont of the wornd co the the ameco bere bed the trestear at or anding the und the cupperte the pring in susin ans and of the the rutad tha s and thet if ser tor por ald ant he lest at ous ar on whe sustint </p><p> prester ss ape the pore tha dis an the the serstin s averenen cond firt on the wion tha morgens buts ans wered that the coulliac and the
# 152m 33s (1110 1%) 2.0667
# 154m 12s (1120 1%) 2.1992
# 156m 22s (1130 1%) 2.1147
# 157m 47s (1140 1%) 2.1897
# 159m 17s (1150 1%) 2.1285
# 160m 42s (1160 1%) 2.0916
# 162m 9s (1170 1%) 2.0760
# 163m 14s (1180 1%) 2.1315
# 164m 19s (1190 1%) 2.1230
# 165m 59s (1200 1%) 2.1470
# </p><p> re ther and fore to that romerthat on the giondeg </p><p> the save the comaly the pored the bertsen and had and aming the stion the s intera d andstin the aniche mrecreat ond che the gere chen the  formand in thes ing the he compertor ded be the and the stresis ald in of the southo of the ceradis an the suress butin the ther pors in the deac manle the hat cheat bered and ingon mo then the foruss of in the pares ano the for inss in the dored po consing the the din mand the now the she red
# </p><p> ar sof of ch ted ale he fiche the stone the the cralland the rald pranted the diat on ant recingsto no profic mons an mreand tho ghime the copelin than shaus in calice tos arecentor the kous in saris salist balls in thare for in s were ssing the sompres che wall of the the ghereding the re prote tof of the prancessint on morating ro the porsint an the alatires she restice the d purite cuthey on the korest ond comedrthe bat ing oned the pas ade the has couple the the deres and be compithe
# </p><p> the head and inst the sters and ye the thed the coullon me them the roucs as ingerat the ding oved the he patien the merthe puthe sal sed bollay whe la the tion the bathe stand the mint on the pars wis anded conded thaid th the peritit the firelticluren ter ant rof he she f opersat on ires and ate coustien the ted the the comperitha the rectint whil the ure the molly and beecon mare thin the pectedent the  mathe sed thes and be the mingenit he lad he ce for iof rof the pereed to sed the f
# 167m 51s (1210 1%) 2.0867
# 168m 53s (1220 1%) 2.2129
# 170m 8s (1230 1%) 2.1257
# 171m 32s (1240 1%) 2.1078
# 172m 42s (1250 1%) 2.1574
# 174m 0s (1260 1%) 2.0862
# 175m 4s (1270 1%) 2.1514
# 177m 27s (1280 1%) 2.1072
# 180m 19s (1290 1%) 2.2605
# 181m 33s (1300 1%) 2.1304
# </p><p> the porisin the ded bint en the morid </p><p> ar andent in thed mrale tor ing noricand on the the chen chit tica lome soppent at and bel the co the rsing tore pa tadent thet haing and the s ore the ced the marins for mate the mant he cand the sof ithe detret the hat on the cound was port dere thin sising of the s ancand in tad he ffer the forte ment the woul coll there has the ses and ing ther the con the chand to the the has ard cound mont ont bes ko thed to nocter sour she leded thikn t
# </p><p> the for andent whe anis and whan at the ware the sandefir and ate tous ar por whe s ane tor he poandint la coming tor wis the at the compicing thas fore nothe don wine this war the sous be comr he thes wasc and to the  facker monter and of the couner bithe fard bot and sa buckeand no the costicalat on ther mont mosting the meats the sper tome siof anderty chat sous in thes and in sat ous il ho ghes and andes the the por anted the be surss an the und whe the sed in poriclint and be s of to
# </p><p> the ray wing that ous te the forma brave the s werked sing the rours ing to tout the ware comere the fre the he tion las pres sa the the mont ate to for angof of the montin the foren the rofing the he demermeris in the dead and of the then tor mont of the the rofin the to that ancould th thed te the the mate thin the as at and sof ica in ghite to tore the che ntiching y and monter the  and the pard ing the sian the compret bes and thed the hes and the s andein the to the porestin ther mon
# 183m 5s (1310 1%) 2.1612
# 185m 4s (1320 1%) 2.1530
# 186m 10s (1330 1%) 2.0906
# 188m 5s (1340 1%) 2.1539
# 189m 15s (1350 1%) 2.1443
# 190m 41s (1360 1%) 2.1204
# 192m 9s (1370 1%) 2.1233
# 193m 51s (1380 1%) 2.1919
# 195m 21s (1390 1%) 2.1521
# 197m 9s (1400 1%) 2.2322
# </p><p> an who the chat ant arithe fore the dustiens and mestion shio shat ous sa diclly the perterest shat en wathe sseding tol bectald andere the porsermani ghe ter seperted the doress and yald ing tor the cha der conctef the conthe pore bont er the merussid the andestin the russiag the hed ais wats an wout of the the cons in tha gov whe ne prome s weromes an ater of the corred the will ais of the sursing the wathe deat in are would ing prongen st of in the contern theress and to west in the th
# </p><p> the reand the will and in the s ond we thes and and as and he are he ther dove of oun the reste the the work </p><p> in the sertan the for ar buches wion the neser and mact on the than the ches ing onsa the buthe s acerven the wall and the  wall tow the sian wrutha s and ingeden the rand ceathe wis the coundit  he prome to the the the predica the pormering dong medert on thas inge th te will wis dint and the sous the meruling the deruts and could the cores ande stent on siald int al the m
# </p><p> an ler seracound aid the promichs and tersed bo the rusith te portict whe he fors an the mint in that wathe shar won thous the  arerede the the the coble covit  he thes atre sed were the ver and that re sipustion wathe he serestine the reat in the stont on the cunthe thes ande the comerimand in nof re wathe be the tors insthr couthe s ane rectint as in of in s and revading and mor tha t thing the wer misist and chath the shes and the count an of oussery hat the ter hed comercente toin the
# 198m 44s (1410 1%) 2.1233
# 199m 57s (1420 1%) 2.1615
# 202m 5s (1430 1%) 2.1751
# 203m 23s (1440 1%) 2.1368
# 204m 27s (1450 1%) 2.0980
# 205m 58s (1460 1%) 2.1172
# 207m 7s (1470 1%) 2.0927
# 208m 16s (1480 1%) 2.0791
# 209m 38s (1490 1%) 2.1056
# 211m 3s (1500 1%) 2.1152
# </p><p> the rustien the mant rossiane save to nerand foreat of the fored for bution th the shat ous the fore that de the he cemere de the perted tow shing the maverof the commint an minty the sover mont at of the s ine the nt thing tho and he rume the ffricincint on the eftro the ande the cound tho med wer dive the chat wish worl </p><p> the gove coutity is won the anded and of the ar porit the of ra pore gover for at ing and of restha in tore to he latingat an of entere prome thes ared th marit
# </p><p> and andest the ill buthe se the der tor poreon th theruss an er mend the ges she he mere co perion and burine then the but in the sila dof the fiscome that combers ingit on whe s arices ded ting er af ers of there some the sillead bo the nis of the the portand in the doferiss dithe s in the andent mait the star monceres in the promed antin ing an whit the the s pprice furs an ater inge roping tor me perention the chongeno for ald itile w ole the that enver mandert in the the the sharit of
# </p><p> the aress as ary  he pecind to the pres in coming sove the inglectorit wor surithe nomre conthe rams by the buss and the puriman mont res int one restice here proned the gof at le ffre weriction the gemeras are the sed the bel cound st on medint thes ders ure tores und ingerts in ared are pare cont wast an ore off cemming no chat couns ion then the duthe nof compring then the rever tas the compars wist he punitho for he nel by the and ins of res ialland the rester mofor the campors bain o
# 213m 48s (1510 1%) 2.1856
# 214m 57s (1520 1%) 2.0516
# 216m 17s (1530 1%) 2.1322
# 217m 29s (1540 1%) 2.1158
# 218m 56s (1550 1%) 2.0776
# 220m 15s (1560 1%) 2.1182
# 221m 52s (1570 1%) 2.1195
# 223m 8s (1580 1%) 2.1307
# 224m 39s (1590 1%) 2.0778
# 226m 1s (1600 1%) 2.2748
# </p><p> th whe the bustige and in the comstion and ses ame t ande the sares the menthe thes and gover whe warg alis ing towith the che purstaling ther the comprisin suld of the rustion the an the rofer ale ramint an ther he and tor wert and ha dole s aucelit inal with ared se the stered in the prome in theine the serdent the ges le teatien the wer werthe sere sian the sean er mation the suis the and the stim the ponte the shan the the deas and ing the sussin ard russiof the sialls sats an thot mo
# </p><p> in the exploned tho sies and the the s an the suster the chare the  lated the fore tho porat expere the fian and to ther ser coussice fommint of ie s on tore the siad distion the be the grestin ons and reans ware shas ing the teat ow or pround and comenge so promean we ther ton s thele meste the s andentrac ares of cher inme thes the has ingy coustiand en wist on the wis ane some the shing the the sted the  has mianclon the ce the couling the hes are she romat </p><p> the ame rialling the
# </p><p> bre todem sha en conien with he the russian the peatid we the ponce or ala fompressina so be thor ane reas is ans be the coule t at ingints buthe the the on that me concen and withe the pore co pare the khe ssing and the andedint rover lo ffore tion the merred and athe er the sutid the and the meris in the then ancessare s lastinge for andecoming the sthe natie the expromin she sise the s areveris se he tow he andert wed ares in th aid suscon the perolling tore the pres an shais ied tod i
# 227m 6s (1610 1%) 2.1767
# 229m 19s (1620 1%) 2.1279
# 230m 50s (1630 1%) 2.1306
# 232m 18s (1640 1%) 2.0747
# 233m 53s (1650 1%) 2.1598
# 235m 10s (1660 1%) 2.1525
# 236m 33s (1670 1%) 2.1347
# 237m 50s (1680 1%) 2.0511
# 239m 24s (1690 1%) 2.0730
# 240m 28s (1700 1%) 2.1440
# </p><p> the s ator tho shat aive the pratict or ind the the ralistinit the sersengene the sere the porsiss wo pray pento co porsing ther mede the woplang the polmitin shating the co the thith and atis the fore the lead bat the fredian tad palis the me that and bous are the grestar whe sta bouthe the ramint insing the roven cound worke the wert an inat of repremanit </p><p> an the cesting the ghe patir en the the  arested iol he mongecen tid stan wathe poris no thars the he ingent on the dera core
# </p><p> in the and bent he dad buthis astite the tore be the couling that monge be singre tor meraid the alitas ang of the serted the or aromain toto the promeding the arestor as in thed and butis iand toratsithe foreabe wis prote the the for monce pay and the tores vonted the omprome the wowhe d ther mandere then chepres and ouss an the galle requint ha d foreto be the cound the the an the whing siand ande tre bes are the ghe tous the as ing the fore se porice ppored </p><p> in are cominilat ons
# </p><p> mo ing pented to thed the ale pate the gater an the peris and ent west co pube the ras ion the burs ar ablical wis </p><p> me merelen the rad poove no peat in the sastiona d oublion on the porsion the ouss and the hat of the her meat on the sof rat red tor en the the der ssing the stores int ce presing the ine sove the terely int of the areand the proment in the ther marivas and poon in whe dain tor arcoun shas andered ingits an ho merate rasian sove the perecon the s an to suad an ander
# 241m 56s (1710 1%) 2.1750
# 243m 15s (1720 1%) 2.1408
# 244m 33s (1730 1%) 2.1605
# 245m 58s (1740 1%) 2.0850
# 247m 14s (1750 1%) 2.0965
# 248m 35s (1760 1%) 2.1212
# 250m 27s (1770 1%) 2.0458
# 251m 42s (1780 1%) 2.1845
# 252m 52s (1790 1%) 2.0919
# 254m 8s (1800 1%) 2.0793
# </p><p> and now of re cound in mina nor tor in the porat in the purs and perate tha krister suthe  the tall and sam stion whald and red tid the stere the  whel the ancon tor and che har stent of or meding tha deed that in tory ans the inge the tha russed th the with in sulent on and art on mand the fican the sembice se wall on that of chere rew  ha keralid sthe way andere for ine licen tol in there bat red and nous in ife mrais in and the sion ta the at ous ir ar and the kerte nor pontin and and
# </p><p> in tha dem the wishe red ing the tewith  he medinf the and ther beres the remeriss ment the s ar pued in the poring the pornace me tering thin wor and at and and rom wand no he pustien tha dee stime nof coule at and the con the the sian the bes in the pees an hit wion licaly of inted an anes in the of the s oredring the periting tow ur peris and wial in the cally ing the surs an that an and the consing the of the seme the moned for puris sopropaling the gent the was cont on tho porsian st
# </p><p> th suma te the ching at onol con the be turis and ian the buthe  for me pore s ande the remeriss at and ing and butit repray fo derithins amint the d of the pontin sustin and ther suthe s weringen rector trat on the cound bustine forice forit ware werd ict ous be the pation the tarestin tho gor and at bee this the tor mant an the riss an and the ser bat on the rusing and bation the finte tralit the sian the the rand are wo le woul at onsered io the sund porian d porean and the ge alat of
# 255m 7s (1810 1%) 2.0908
# 257m 39s (1820 1%) 2.1400
# 259m 1s (1830 1%) 2.1113
# 260m 18s (1840 1%) 2.1402
# 261m 33s (1850 1%) 2.1248
# 263m 2s (1860 1%) 2.1444
# 264m 24s (1870 1%) 2.1354
# 265m 52s (1880 1%) 2.0686
# 266m 57s (1890 1%) 2.1385
# 268m 22s (1900 1%) 2.1294
# </p><p> the stires ance sillssing the the shat the puris and chirlagn teatit the prestice whe werl roming are the compans ars butin s are the s ffect the pormint ant che councon toveres and the frecain the sound then the for the reats and the stin s ares in the wos couss in posting then the me the ssinge sormen torkinc me the cous in the russion and protid the tho sursoug the parice sherelly whit sed hes an wiol aresed bo the remen the ans in the hes and iceris said fore mas co pormed the an wath
# </p><p> med comblit or vee tores ton the comm the he paldes an alden tha d ally the niand the bed come pres inith the mallarg the cemres an the cearsean s ons ang sover mos andeed wath the chale merate dand for seat one comprement che sursean w int cout the s ithe wiel the coled of the ras and int ing te toon the pering s atone foreving the ceald the perne seas in the othe s aldering the res instor the comprict on the ersereat on the persed sile the raid that we ha suche preat on the who miclicll
# </p><p> the als ance the poll of experse to hed tad thil so st he the parlice ffor athe pursian and the commrina sta seas ing fermrin wive the s male we ha d fice tingere sian the couthe  orstee s sher asted wall ing the por ant has mallod the sexperins and arneris and crupling the s ar sedeer wor he fore monts and be the tion montar bo the sures res inal and reard the fore to sald thas in the condenit and comos and andelo fore shat be porsis ans anite or and monthe some the bertich the sthe the
# 269m 39s (1910 1%) 2.1194
# 271m 1s (1920 1%) 2.1378
# 272m 6s (1930 1%) 2.0597
# 273m 13s (1940 1%) 2.1365
# 274m 19s (1950 1%) 2.1255
# 275m 38s (1960 1%) 2.1192
# 276m 45s (1970 1%) 2.1440
# 279m 32s (1980 1%) 2.1140
# 280m 48s (1990 1%) 2.1046
# 282m 22s (2000 2%) 2.1475
# </p><p> and are wer best of arerint wase no pare wher and of the restove for be tores the ctore the popering the combente the tores in aredeatie sale por exte aller and iald the inicluns abe that of of the has it ale the store for and the on tores mant werucrian wathin the campromine seva </p><p> and ale red and int the sats rutily ress and ha force forean for and ant tore tor and the susith s aplonte the soperile s aniss whe conctis peris in then ant and here not he wer the ass coungry to balle
# </p><p> the res and and bouthe </p><p> the  hathe govere the paring tos ato firmeding the buls an anderis of the ralina pored ine pore nond armand werker the s bald in and ter ous bat on the stat ant and buto for the the sutita </p><p> me the of are the mont cheprome an cominy experted the sillack of the preminang thess and he warland the grensto fon ficandeproms the aren the arsing mented the wer anis were the porgerentat at the ghen wor inge wor buts ious ian the the seme peris an the propling
# </p><p> the russtin lacinge an baris ane porting the and nosian in the and and to the the s formestee the buthe sedern worm </p><p> the poris in shes mant comprestint on the tinguthe d ans iffreden the prof the mreland we ha d ane buthe s bered comproment bound the brentid an wathe remanin and at on the perted co palliag and thed the  ingraling the peringer sale an the russ an the reatsor thes aples the s ate the nof the novions areare the monerthe  ffere somp ans at oned the comenald ber mentien
# 284m 27s (2010 2%) 2.1146
# 286m 5s (2020 2%) 2.0931
# 287m 14s (2030 2%) 2.0844
# 288m 34s (2040 2%) 2.1693
# 289m 43s (2050 2%) 2.1060
# 291m 3s (2060 2%) 2.0639
# 292m 6s (2070 2%) 2.0994
# 293m 13s (2080 2%) 2.1307
# 294m 27s (2090 2%) 2.1649
# 295m 41s (2100 2%) 2.0478
# </p><p> and the desion the ther mont be tha ken mant of the in the reating the durt of restian </p><p> the reating of porte te tore poreate t ane the cound at an wound the an the me the ans andes an the he promest more ns wert the palisis ste then mon wome the buthis se pormonican the wathe n the and the anom </p><p> the lous wa lome the ther and yer ofles ahe fore the romern of rut ion and chere mingente tor bera seas ing ber the suring of it o shes ares in the bura the pontick pormedis la bute
# </p><p> s ane that oncins abe the lowirn whe ha destian tover and tounsin and the wouthe s of acoleand in thit the would an woul pion and he ans in are side the an in the porseaplo seruntio sha of res an sustay the govica sored ar he the fore sha de could and he ace allore shat the forecenit of ancoule and the forles suthe sor ast an fore shat ond ball and the  of ousin the as andent conterte the s whe ande ther conted ane riant nover and at enores and buthe suad the the conthe salion the someres
# </p><p> in tole the comanit the the and bathe pursian sonat of the wer und in the pare the wer ha whe ver comer boof buthe in the la the rale tore the wion mand the r will no doppen by an the bule tho mere tha d ithe for ghous we the he sed in ther the parged and dof the ante ing be surdent and the poreand be the ther she to the sted for thall an andey ar and the sound th the serussian are sait sion the malis ande the sion and ther bector the mere poreat anit rombe the sore toves ian pobyund lof
# 297m 21s (2110 2%) 2.0958
# 298m 41s (2120 2%) 2.0995
# 299m 46s (2130 2%) 2.1214
# 301m 9s (2140 2%) 2.0294
# 303m 29s (2150 2%) 2.1539
# 304m 44s (2160 2%) 2.1296
# 305m 52s (2170 2%) 2.0295
# 306m 57s (2180 2%) 2.1247
# 308m 13s (2190 2%) 2.2025
# 309m 31s (2200 2%) 2.0906
# </p><p> mr buthe sore that the now he fer ace ber couplont ther mina loricen by the that se rom tho chine des arits an the puor an wourd be the he bouthe pors an of aming the prone se plotien the and the anite he ches at couthin she ofiche n copprit ont exponsis the the aneriss anilicho s alome the siat of ther the bect of the heve the and of the ale for an ber the sore the the s acente the sure avertar ssint of the chel buct on chish in the and the hion an and wer male to the sstide the prontion
# </p><p> the rus the stothe s ouclint and bound of the govit the the re ceand pons were sor at on warken the the ported at ha pollate the peruts as whiting an and hake ded monty the he deres anicl ss in shain tof whe rofint carled and pro pore the he prome s int ond worn sus in whe s perin th seard and wha d and re are serear of the chethe sout the  nelecoun whe he presed mast and the nont the manust ar inell monteras an ate the che but ie thes monto th ro buth the stat on the dery the precusis ab
# </p><p> ir ales ant an are in the hat eropling the s ate tore the the couthay of the seat be the cound bofor war he inger anithe seat in the way kove ther and the s wertho sion coundey are pors couthe sares we ha dome the hathe s ane the s at on the share serald in the what ha don the s ond the the s ans an the seat in the tore the lowe the s ane wor sof the he wore co pantins best ing ing at on werthe stof the  fored fus in thers chen the che tor ing the gresen en parestias of conte nove ther pe
# 310m 40s (2210 2%) 2.1497
# 311m 48s (2220 2%) 2.1300
# 312m 51s (2230 2%) 2.0700
# 314m 33s (2240 2%) 2.1656
# 316m 32s (2250 2%) 2.2132
# 317m 43s (2260 2%) 2.0885
# 319m 36s (2270 2%) 2.1019
# 320m 55s (2280 2%) 2.0258
# 322m 3s (2290 2%) 2.0707
# 323m 33s (2300 2%) 2.0986
# </p><p> in the sion monks sore said tha s merialde tor and the the te cerale sour ion the sastion shat the rove tod promint on aremonto for the tore the fore and he onstate the soone whe s purias an the reatit on the russian ing of the meanden tome cowath in with sucantit ar poratin sorspackat an thar sian and the ssain sere the pored bing and sare the couplon the surition the suster e tor ancon monomr ha dederast in that what areas and promediot he the formestin the ussinat he ther and the perin
# </p><p> the thesedent of the of ous in indere the sore the purserof tha andere to sha cenonst reppertion th the and the cominitin s ander of the seat expreemr y anis ams bound andente the pertion the s ingeran ing tol ghe the nussian shithe surses and are de to the cower in then the the at in sedent le co mint er montas ans ithe sillentig the perollang and the the stit of the patien sof che tores and ha kis te thes cound as and al morise porsing the has powith the really to whil alingat in she ss
# </p><p> nad the sain sha coung an thit the seat </p><p> the the ho coucono na the reelling the ly the fored the ghat on the coun buts ance the rustion was and al ous ig the excenteres ar pecter aly tha so putit on the and and the reppon said at of ore to bure and at onstiga as ing the cound and in tre sion the wion and sor sed anme sad as ondegend the stor ing the seres mand paling tor pars in sederong the formadis st ang tha buthion the cound the the prone fore was aner sed to the poree to s are
# 324m 58s (2310 2%) 2.1285
# 325m 53s (2320 2%) 2.3282
# 327m 14s (2330 2%) 2.0688
# 328m 38s (2340 2%) 2.0459
# 330m 17s (2350 2%) 2.0633
# 331m 42s (2360 2%) 2.1855
# 333m 11s (2370 2%) 2.1038
# 334m 33s (2380 2%) 2.0786
# 335m 49s (2390 2%) 2.0923
# 337m 13s (2400 2%) 2.1105
# </p><p> buthe ded and ous of the car and the s an monteat an would ins ars are the and and beed the rowithe s aperies ar he herussin ing and buin alling the uns in the destion the he nontant the sond </p><p> ing sias the anded the roficand the wered the sian whal baling the walling then bitid th the repreand mostho in tir sien the s ale barn an suress of heruchian the uss aves ar ay presedin and he por and ghe en tollicinat that the storee fot terersead ro pores ine thes teer that ef the rurs an
# </p><p> the russiand chated sat on and montte r and rusin the cursing the suid bo the theresing the perthe s atel an precelas andere th the expertin the ject ond rome the suthen the pare tonce and the sserming of the sis at on rulint whil  he prong tove io thereconcent of whe anderag of the raund ate the ha decon the ato wer ares ane promith the purne bole mont of che reat analis ite and bo the wis ano srised russian ghe the sile ter and se tores forme the shat ceallad mont on lecente the singe s
# </p><p> mr the rveriming tha ked profico propels of ime the cerutin thit shat the was and of rome the pormegever she pration the roms ines inst te tast at on experto beracon the s whe wes </p><p> ing the be the prome the sicllatin singens an warling tor perat on the serte toras ant andey and the ris int ont or andet the sure ald been the the s bued at be the on tho stale buthe chate the cond the at would and in the prepratid s ascintain te thes af of ar pertion malice the the seate ar and it the
# 338m 32s (2410 2%) 2.0965
# 339m 44s (2420 2%) 2.1113
# 341m 7s (2430 2%) 2.1353
# 343m 27s (2440 2%) 2.1147
# 344m 52s (2450 2%) 2.1503
# 346m 21s (2460 2%) 2.1380
# 347m 30s (2470 2%) 2.0905
# 348m 31s (2480 2%) 2.0702
# 349m 32s (2490 2%) 2.0822
# 351m 10s (2500 2%) 2.1304
# </p><p> the und in the mren reas ares in tice bation and beat en urita conatsing alis of or mern the sing the be singel whe derusin whe deat in the  anders </p><p> in the an the anderted tha d pels an the the sond manthe se butin the sted mr bute that ins in ware ant ans and in the russin sion compros the  he pursian recoust ans af thes ares in the for and ho fice fore for the rested the kes was ar shas wisp </p><p> tha dectare the suplian the the rome whik s and int he preat on the are paris ar
# </p><p> the hing tha compecand of the russis agen the potion tor the poreeras and sice paris in in atere in were res in the the memint on subila d ance stom sh the che and then wowh of ine compris at on mrathe se the on toor moris and prasid monting the s ance aid the pareas at bald boun th andent but in the compromen tha ghat we the beram not on buthe coun the chat chamr wer and wast end pround ba the and the puring the ssere the sedithe werting the lict of the and me the andeling the for ing th
# </p><p> on the pore to f inte sto the precing to for ha porgeso the  anded the chay comporian sussean in age mare thouc and the comprome and yeved and theer shaid in compars and ar ande sedesto the fermized and in tore the det could io singat of re theing an thes whe ha kow the rosel comiciland wath of ice that oruss ar poread for aror sad and or for frame the resere the on as oupling an comorn the lame the sele sian worl ar er as and be the from the russime and wark maker cored co the ate and co
# 352m 22s (2510 2%) 2.0528
# 353m 16s (2520 2%) 2.1138
# 354m 17s (2530 2%) 2.0871
# 355m 26s (2540 2%) 2.0691
# 356m 39s (2550 2%) 2.0282
# 358m 9s (2560 2%) 2.0722
# 359m 35s (2570 2%) 2.1271
# 360m 45s (2580 2%) 2.0815
# 362m 2s (2590 2%) 2.1308
# 363m 31s (2600 2%) 2.1250
# </p><p> mr buthe shas ing the ande tha ghe rementinis ander colling the mere the whing that res bullignot on wath the cente sald bes and noplewe cont and benthe sistion that of chewish if res anted that ar aut in the pron conte ras rustin the perteden sthe uns ing the res in the sove the wathe pront ar bouking the sthe the ould and at on ticted the dericares sof an merill and tha ker ins of the mbet futhe s aperand se forming tor bor soppring the compenced the of the coplent that mestines me the
# </p><p> the som th the the stise d the ball the secullian and ilaplisted the and the rysting the reastar she cemont the mestid at duthe s ander touc aid forero shan the best whin the the anit hes on the in the woll the the of pras ins an thit ce the the pore dof the shit whe cound </p><p> of ore then wnut the the stome wert but the ursese th the fore with s whel and mo he preat be niclled an mont an sed picines ane the ed ous ine for the rustit tha mont the s and the rable den the rastion  the an
# </p><p> the sat on whe dablice tovered nod nevien the nale bot ar andent and walinile th there the foref re thares war meat on the and restian and the nover mont the boll wer anderion deat the expersion wor the fer mracling the boun tho he eres in the f alliges </p><p> the side th ted tom seate the red the the warl the wer the war couplonge bustian </p><p> ma lopreand an ther and the ras ond wor he thall an andent row in the sand bat ofor the be woun the suseran mont whe heront an the seling whal
# 364m 48s (2610 2%) 2.1399
# 365m 56s (2620 2%) 2.1439
# 367m 5s (2630 2%) 2.0790
# 368m 17s (2640 2%) 2.1130
# 369m 42s (2650 2%) 2.0955
# 370m 51s (2660 2%) 2.1089
# 371m 59s (2670 2%) 2.1286
# 373m 20s (2680 2%) 2.0523
# 374m 16s (2690 2%) 2.0546
# 375m 40s (2700 2%) 2.1226
# </p><p> ming tont menthe  for mo the s and wial and thee the shared of chain sian and the lect or comer ar buthe s and an the rasilion the conte he pare wares iand at thay an chare the bitis seda anatis an inon the for as in are tof the raignte coudint of the comenis the puatid tod pontares aperling sicenthe sedenge the mine and ropectedel an the serastow thas ingres bo that row ingand the ramins fiom anteras ares iont inat on the ced tho he rusile in the fires and whinge bat rathe shat ous ine p
# </p><p> the blining the the at of the tay some whe his aid the sithe he wheche coming the romble the free the the s werethe cheredstin ins the hever monit the peringer colle then the the ston the pestere the sting on pasin the s auts an wathe rusinge tor ander and comatis an mares and areres the restid the houg in sed toute tar souns an the rusing the he ase tho d pore mprice the stay shereand the sictere s and an the und the he he russiat of chime the uner onthe tha fore tseas ane the ster and a
# </p><p> the kires of he withe ffor are sadd in the cher sead sis and withe soress an anded en tust of ghere te the serne an lembee tred the ras ial comperion the ins are sureed aila d wathe sthe were poncate the mitite ing the couring the somp of perien the pion inaly that of the cheleding the and enothe me that en theand thes ing and whel sha derusid the comeand the res inethe d pore the toon the rementiles ing the s minte ted on the sicall en and emane med inat rasins an wishas are when tha mon
# 377m 24s (2710 2%) 2.0653
# 378m 46s (2720 2%) 2.1010
# 380m 2s (2730 2%) 2.0463
# 382m 4s (2740 2%) 2.0982
# 383m 3s (2750 2%) 2.0821
# 384m 51s (2760 2%) 2.0767
# 385m 54s (2770 2%) 2.0374
# 387m 4s (2780 2%) 2.1291
# 388m 52s (2790 2%) 2.1469
# 390m 9s (2800 2%) 2.1843
# ...
# 558m 34s (4010 4%) 2.0339
# 559m 54s (4020 4%) 2.0990
# 561m 8s (4030 4%) 2.3137
# 562m 29s (4040 4%) 2.1329
# 563m 30s (4050 4%) 2.1360
# 565m 7s (4060 4%) 2.1446
# 566m 14s (4070 4%) 2.0534
# 567m 43s (4080 4%) 2.1242
# 568m 53s (4090 4%) 2.0680
# 570m 16s (4100 4%) 2.0481
# </p><p> the tha in the thet on for chana dost be the some the corat in withe re consithe arg porn werl the wert che hat and chen will sion are the sere sian camian on to the shar ale the se the reat ch some than and artion the and the ram and bo the prent an ine hing arme </p><p> mr thes ande the ofar sad of th the buthe s waic sovin there ropent the stare sove ale be the merecont of the an thete toris an chere the the poss wall he he lust and me ther bathe har  atires </p><p> me buting of thite
# <p> the ne tof are beant the s andsint ghat bous wall be the sead ate ta he ondent the ally an is wor be sian and bullied the the experisin the troliss se the bustion </p><p> whe ra charas ar of the ruster bonk sian sing in the rof the sore the rome thate the he nover meale the st arid siter and ine the tor and an the rame the counit of the nignt of thing texte te the ralderes ar bembor and red and the bus ia sain suse tole the dallain tha ing lowere tho and the he here den the raston the premine
# </p><p> ate tho an ard store re dict of the aris ar inerent </p><p> but the pee tre the eravio shaid che thew the the commint the bay he couthe  and mate tore tha the por tome the said and on the nexerutin s and ex crestit de thar and in the rion and cheas ing the the s amingos in the part to the the ater at me nithe the reme tien the reruts of the he non ing ion thit serte naming the  ware will andere the polle s the sicens an andent ro tha dem ther the denat of thes of the tre than the protid s
# 571m 32s (4110 4%) 2.1275
# 572m 41s (4120 4%) 2.1311
# 574m 1s (4130 4%) 2.1256
# 575m 25s (4140 4%) 2.0844
# 576m 49s (4150 4%) 2.0682
# 578m 13s (4160 4%) 2.1928
# 579m 44s (4170 4%) 2.1493
# 581m 28s (4180 4%) 2.0514
# 583m 22s (4190 4%) 2.0794
# 584m 33s (4200 4%) 2.0531
# <p> the compristo surita ns ares ian ha decaicin thit and he sperinat on thon there wathe whit se no dentit the seruline surdeas of are of hat aus iate tove wa the res aren the steelinaco for as inet comiticantid the the sthe he seares and sow in the conil seathe sian lare alonge caly cha thes in the prestian me there mone mo bite sting the and rovereveras in the ante tha che formeal the s are the chove tien the s ancaill of is the rustid mo the sursig the sase mart </p><p> me the co the sorge no
# <p> the fering the commente a doacinat on the cheve tor at ation to tor alling oustion tare s and the suling ion tor the serit on thes ar melidente the the compresedent the ars irasker an ould ast of rus iant of the at and cariss an the silion </p><p> ance ffricinn tor companim that deat of buel ard ar singe tove the laris aniticasin the ceris ant ar iomprisit ous tat oncention and the raskere the gha the siand ar sha derecte and the ussaid cuting tare thange wa the deres she dere that he sone wa
# <p> he cored ports ared ber sowat for arser an the comint and the tion the rate te to aud in there stin ilats aid the aron bur thes ameng the the he prestat the rusing to the preding the male tore withe s anter an and that on anderes in the peritin the come the counte tad sian s ancenor ariss wal the andersuris ins sian arels and the sewetha d onger and ins ing the deng tont of the callede te pronit on the same in the gerent of cheres ant ament ane mone the che and ars ianmance pursiat of ard its
# 585m 41s (4210 4%) 2.0901
# 587m 19s (4220 4%) 2.2585
# 588m 49s (4230 4%) 2.1130
# 589m 59s (4240 4%) 2.0351
# 591m 14s (4250 4%) 2.0666
# 593m 14s (4260 4%) 2.0952
# 595m 46s (4270 4%) 2.1154
# 597m 12s (4280 4%) 2.1230
# 598m 25s (4290 4%) 2.1571
# 600m 3s (4300 4%) 2.1022
# <p> buthe sever mpok in thethe  office an whe s oreas and tho ghan the whe ware tore thail the ceand in sustea for fare sed the porte sor thay wass are sa powith no ledets re ther and thes and bouspro ste tor surs at russ as perens in the putien the peris ano for the the for fore canor orvis an at peats ar monter ing that oncoume theve mo ha he perestin the rustir she wast are ne then would ar the remr taly burkion an buthe s tores couth in ontere to tho he herealy ared she poreat on the kevored
# <p> buthe mone to the suthe sion tous ias inerung at the the ardent the pred ea romply armer ioply the he le bed er and the purias an palend no prestion pore whe r ange the rowe ha d andere the ore of the he worl whas ant of che hem the pabion whe derthin wall belly ar andent ghed sparis thay the pais and the porecen are the res and tho seat an the conding wey ha des ande the ss dere mond wes to the the he kove tad to the cous in the covien and than ther an the precon fores of the propeaty ded to
# </p><p> the s ans me that an of denonge the ble sed bate to the und an thes and bo the antecter aling the ghon gove the proplige the an the stine no for the siverte te tora shaun sus iall worg oncenot ous ias percing and ind buthe d me then wion the onden the pored the destian the are fonte to the periling tha he preand reate the now the stie sonded an the sande the pous in the passtin the beraly in to che whe  ther fore the pore the andering rove the ing warle wath anctilliment he her pore the p
# 601m 35s (4310 4%) 2.0511
# 602m 52s (4320 4%) 2.0975
# 603m 51s (4330 4%) 2.3577
# 604m 51s (4340 4%) 2.1461
# 606m 4s (4350 4%) 2.0933
# 607m 16s (4360 4%) 2.0926
# 608m 40s (4370 4%) 2.0937
# 610m 5s (4380 4%) 2.0798
# 611m 21s (4390 4%) 2.0902
# 613m 35s (4400 4%) 2.1034
# <p> the russ an of the wer ching woul whe der maice satrecan ing tore mont on ther mederow of an tha kerge the hay wor he comint riperat the in the w thor and the spere the bele tor sored on the rome ther mr beat on thet an has anget the the rees and ated in the proplit ins ar sian and ing the tor and could an whor the sure he worn the the stereas ans the decon tor buthe dover the the chem sedeng tho paring tha d une mentere that the bait ne morchat on the peril sast on deprent and the rection mi
# <p> the the the fored of there shat dound thie the paringe the sedinge coubling the protid the the expecticand st pont on the ona peato for comection thand the roveris faling tha whe rus in wale dent tomplican and ithe s vertere pore the aing the lessint tho ampors pore the aber and that ar shal tore monat in ther theray whe who ha gereds bean fic and the sor angrestion wist and the pored to pors ins and iand the raquere the warkorn the rithe less were tornig the coustin the sian ous if the serut
# </p><p> tha ke wark ponded mant es bouthry what ha gher wor he mbeit of ice re thatid the thace the wer shes the seriag an thot entor and the wien ward th the keruss an the chivis that of amate the sion the sten the ame the if no precertit the cof or the nexprof de pe toras whe derecand pors inat en thatre for ad nutien walling the he coupltor bo it the and ef the rustian the the for he the warce anenusin to the chathe the gove norghe wound at aniend buthe -- thered ine saceand that of the tormes
# 614m 56s (4410 4%) 2.2007
# 616m 23s (4420 4%) 2.1813
# 617m 56s (4430 4%) 2.0907
# 619m 12s (4440 4%) 2.0880
# 620m 25s (4450 4%) 2.0876
# 621m 39s (4460 4%) 2.0557
# 623m 0s (4470 4%) 2.1417
# 624m 13s (4480 4%) 2.0735
# 627m 1s (4490 4%) 2.0724
# 628m 20s (4500 4%) 2.1170
# </p><p> mores dound in them the riveroment on </p><p> and that hes and on the bure and ine chate now the s wail ant reats an the mant ing the rastions mast anis wath s ander ha dand mon the reass in the rave ton shat of re tila ded cos to than the govereme t an and that on the sain tover me tort wored the  offict on and con mouthand the couno fore th the hive thon tod pornag the porsed no the prestion more s more mortoly ance ton jont wis at on wha dis the meering ion salice the rowith the he rus
# <p> an erestof tho bullead formento to peas porion comrens the derestien and sustian the s thes wer onat pence tor angenis sio ston the  ffrithe s an the sestion the ander the comeno the and ar the russin ton the are sount ous in th tho fice pater ment on mo be ines in tored me the restiny of ralled in tore ardeden the siveront be there in ouss ato the and he conting in to fora the the riseains ar comprice the the paicl wer s ausispon ther the bute the preling to tion of the monte to fore the rea
# <p> ber merthe onverin or the sesperils ar bouks wien the the ming the ontares </p><p> on the soled in the porecolleame the bers ane tha d wall and the promich we con to se nor tient and re mont in the proproplion the  wall sestom the puris al and ched the the her come the ton proned the and be the ko werling the rack ound ar sore inge ment the surof ris ially the pucling that ous ian tad stat the an uting oncenthe soun the roverald the rome tha fin the the that obre the file te topain the conor
# 629m 43s (4510 4%) 2.1361
# 630m 52s (4520 4%) 2.1165
# 632m 11s (4530 4%) 2.1535
# 633m 16s (4540 4%) 2.0678
# 634m 35s (4550 4%) 2.0421
# 635m 37s (4560 4%) 2.1341
# 637m 42s (4570 4%) 2.0973
# 638m 53s (4580 4%) 2.0040
# 640m 43s (4590 4%) 2.1162
# 642m 9s (4600 4%) 2.0601
# </p><p> the fore shen wath of gheered on the coure an ous ian anden the randere fore the peand thin the pares ant he experted stices an mestit wor the sian the perand mo the ware he ruppond the roperin the cousinis the and the be the sount the poos an he leare cound and promant wislacer an the salion of rus ing thon ang the suren the hes ares are the  ald the cont otha d an cered </p><p> the formesis same the s ofol to reat he thered inn the sald ancor apreding thom mr puris whe the sed the hate
# <p> in shes the and heprestin the cowithe realisir and the the breand the he hes ail said the restine furithe an the ponted and the se the persine the sower the s ane warl as incoured and the to the paryed for iof chate to batin in the seat ithe compersing and inis the perilithe and the sesthe and tha cowsted the cound in the porate tor he pulingred the derthe she inge band the stid and the the saree so were sive the sore say sed and bound in the sor prothe sustian lot he rommint the corntin </p>
# </p><p> ar shement on thet and an and fore te the thon ingerist he and the sedene for are the shitha s ar herele to tho colleg the sonted nod hite of mere shas sound pats toke wert hat of the she ware wher serederitin the countie shat ors pustid shate tore manian of chet tont of centicer busine mand the rofer and in the and tor exis the se perict on the mona more butine that enalion wh he ha laprement who bar int and be whend the d the suas and wnthe share sion thes an inge the resed the mintion
# 643m 33s (4610 4%) 2.0735
# 644m 44s (4620 4%) 2.0052
# 645m 46s (4630 4%) 2.0672
# 647m 34s (4640 4%) 2.1739
# 648m 55s (4650 4%) 2.1232
# 651m 3s (4660 4%) 2.0983
# 652m 23s (4670 4%) 2.0537
# 653m 47s (4680 4%) 2.0639
# 655m 32s (4690 4%) 2.1229
# 657m 1s (4700 4%) 2.0418
# <p> ous in the by the copling of the torter an ous int of russian thay urs an that his  hat mantite no chaidg tor mengean th to shat on juntil s veet ce the were thar shin the warthe balita ta tore she reporing the the cometict of thate me that of rathe the comine the cont ins pretid st weel be buthe fore ans in the wore and reat mont an the compresond ta ong the sian the menter sald sover at on was in the porenicand of in the chat nes in the ancon and ef ome rian and ias shat ted bous ay or of r
# <p> n the and istick an the wist on butling and rucher aid ouad in are cont of ackera th sianes </p><p> she he poofine the tere that on the countor and of oment at cally and whal be poon was iat ous an the lowe </p><p> the har ardoncong on merestion ins inat on the her poont wer ghe an ante ball in fremint al the  of ronon that of the tare dor and in the comente tor colling toon ingeris iant ioppritis an wathe pelicimans atren mren then weshe siding tha russin whe dent thes mericin the powion and
# <p> ine somatis of betres </p><p> the hes rsaplons inge niss ar expertin she thing me tompre the proned tom the onden and alderean the conte that  ffor ar inat cove was in toin ano mont the hat en the aling the and pompretin sha der stin ament an ware comprosticy </p><p> but he when as monte tore sid the te coreat ros and butin the combed to th ingend and in toro for the saptor an the recen and colley comprisins in the noreg inge stot of cos an the pronit in the ament anist he the prention and ch
# 658m 16s (4710 4%) 2.0558
# 660m 5s (4720 4%) 2.0156
# 661m 23s (4730 4%) 2.1526
# 662m 27s (4740 4%) 2.0865
# 663m 24s (4750 4%) 2.1001
# 664m 38s (4760 4%) 2.0745
# 665m 51s (4770 4%) 2.0708
# 667m 16s (4780 4%) 2.0680
# 668m 40s (4790 4%) 2.1844
# 669m 58s (4800 4%) 2.1632
# </p><p> am nis if the buthe wiol the rof ruthe stid thare se the r vereatar ourmer berount the aro s and the gat an the rusin tion thit se the reverit an they the count in rofit the pastid the and int of res rovilus bat ke whil the ghes se the ropros bue bled aid haid in the rale ment ored low on whe in the to gore the coullay ared the es ire sarge wor has ira in thand in the singe the the seras inger and tad the bus if chare sova de thing th the freminit tor corment on hald ing ous act oustien s
# <p> at of that restore the he fere to firutsian ind shen mereste the pustiling tor the s at of exter in the raver of ingreat were pursear suris an whe end beat er he whe has reation </p><p> andent ere ptonit the s an out reall bat on the are pore now the rually he aster ane that ess and bout of the the sald the mint an red chate stadest and of and in wat the on are and chall the andertere said anion tor areass </p><p> the grous in share of or ate the serder che conf im the ras ion le the semreis
# <p> int res ing the rems ican to thes an wast of that on the burk of or me that breaid ing tha persinge s ing then the sad the and sind in the ficlian ton the sisthe peed te the count on the the foral and of the ponge promr the and tho for are icon are the the farte tres ing on mreasing tand the proprent oustiat an on the fur the sarig the se wered be pares ta the mants bull ked aningr bust ar port ace pors arthes are coment of the serelvorath tork what  he prome the are the wist of on are talk w
# 671m 15s (4810 4%) 2.1669
# 672m 35s (4820 4%) 2.1320
# 673m 54s (4830 4%) 2.1112
# 675m 4s (4840 4%) 2.1454
# 676m 10s (4850 4%) 2.1639
# 677m 32s (4860 4%) 2.1230
# 678m 57s (4870 4%) 2.0092
# 679m 51s (4880 4%) 2.1098
# 681m 5s (4890 4%) 2.0104
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-773326697523> in <module>()
#      22 #     rnn.hidden = rnn.hidden_init()
#      23
# ---> 24     output, loss = train(*random_training_set())
#      25     loss_avg += loss
#      26
#
# <ipython-input-12-8e68a2a57c88> in train(category_tensor, input_line_tensor, target_line_tensor)
#      18         loss += criterion(output, target_line_tensor[i])
#      19
# ---> 20     loss.backward()
#      21     optimizer.step()
#      22
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     154                 Variable.
#     155         """
# --> 156         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     157
#     158     def register_hook(self, hook):
#
# /usr/local/lib/python3.5/dist-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      96
#      97     Variable._execution_engine.run_backward(
# ---> 98         variables, grad_variables, retain_graph)
#      99
#     100
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Plotting the Network
#
# Plotting the historical loss from all_losses (hopefully) shows the network learning:

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

plt.figure()
plt.plot(all_losses)

# %% [markdown]
# # Sampling the Network
#
# To sample we give the network a letter and ask what the next one is, feed that in as the next letter, and repeat until the EOS token.
#
# * Create tensors for input category, starting letter, and empty hidden state
# * Create a string `output_str` with the starting letter
# * Up to a maximum output length,
#     * Feed the current letter to the network
#     * Get the next letter from highest output, and next hidden state
#     * If the letter is EOS, stop here
#     * If a regular letter, add to `output_str` and continue
# * Return the final name
#
# *Note*: Rather than supplying a starting letter every time we generate, we could have trained with a "start of string" token and had the network choose its own starting letter.

# %%
max_length = 500

# Generate given a category and starting letter
def generate_one(category, start_char='A', temperature=0.5):
    category_input = make_category_input(category)
    chars_input = make_chars_input(start_char)
    hidden = rnn.init_hidden()

    output_str = start_char
    
    for i in range(max_length):
        output, hidden = rnn(category_input, chars_input[0], hidden)
        
        # Sample as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Stop at EOS, or add to output_str
        if top_i == EOS:
            break
        else:    
            char = all_letters[top_i]
            output_str += char
            chars_input = make_chars_input(char)

    return output_str

# Get multiple samples from one category and multiple starting letters
def generate(category, start_chars='ABC'):
    for start_char in start_chars:
        print(generate_one(category, start_char))

# %%
generate(['economic conditions and trends'], '<<<')
# Out:
# <p> <p> <p> <p> the mericena toge of ere pas anded the would of hith tharo thith the ints on that on ting the s and toren wha the tores the rove the that shas an the poris the ancenter ant ereer the of the mes ine the shat state tele the the and the in to the the weris ine wath res ine the when tid in tho mover mint of and woul the foret derulatin collins wion the ane the s an wore to the ous wathe fored fres an veling the sundery and he tha kos and in <p> the the could an the ins ine the frea de
# <p> the for he kon sico chere ssian he the the thound the reppeling way th the pomelian and comer in the the ame the cheres an the bunice tormer andent he the he ras <p> <p> in the enacin s aplesing the the ante tores allat stent of russian sures on the ere the to ant of the was in the supperer <p>
# <p> <p> <p> <p> <p> the s ine verto to norle por the conat an the mint at ond the wer comed an anment tores the ware derss wer and wath rous sa for sed anme the way thatr int in the diche prolist on shis bate the sed bould the the povichis ariver wer side coment ra ind mestoy the mont in the the surs an <p> <p> <p> the w toread and wat the are sed and the s <p>
